# %% [markdown]
# # =========================================
# # Day 5 - Logistic Regression and SVM
#
# - Logistic regression for text
# - Decision boundary function
# - SVM concept
# - Model comparison
#
# # =========================================
#
# ---
